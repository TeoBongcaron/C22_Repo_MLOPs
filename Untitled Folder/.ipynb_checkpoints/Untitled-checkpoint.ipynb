# %%
import requests

url = "https://raw.githubusercontent.com/USERNAME/REPO/main/models/sentiment.onnx"
response = requests.get(url)

with open("sentiment.onnx", "wb") as f:
    f.write(response.content)

print("Downloaded sentiment.onnx")
# Out:
# Downloaded sentiment.onnx
